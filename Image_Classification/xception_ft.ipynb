# %%
import tensorflow as tf
import numpy as np
import os
import random

tfk = tf.keras
tfkl = tfk.layers

# %%
# import splitfolders
# splitfolders.ratio("training_data_final", "split-data", seed=127, ratio=(0.9, 0.1, 0))
# Out:
# Copying files: 3542 files [00:20, 171.22 files/s]

# %%
# Random seed for reproducibility
seed = 127

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_base = "training_data_final"

# %% [markdown]
# ## Splitting in training dataset and validation dataset

# %%
img_height = 96
img_width = 96

batch_size = 32
epochs = 200

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch = 64

data_gen = ImageDataGenerator( 
                              horizontal_flip = True,
                              rotation_range = 180,
                              fill_mode='reflect',
                              channel_shift_range=15,
                              brightness_range = [1.0,1.1],
                              zoom_range = [1.0,1.25],
                              preprocessing_function = tf.keras.applications.xception.preprocess_input)

validation_gen = ImageDataGenerator(preprocessing_function = tf.keras.applications.xception.preprocess_input)


train_gen = data_gen.flow_from_directory(directory="split-data/train",
                                                           target_size=(96,96),
                                                           color_mode='rgb',
                                                           classes=None,
                                                           class_mode='categorical',
                                                           batch_size=batch,
                                                           shuffle=True,
                                                           seed=seed) # set as training data

val_gen = validation_gen.flow_from_directory(directory="split-data/val",
                                                           target_size=(96,96),
                                                           color_mode='rgb',
                                                           classes=None,
                                                           class_mode='categorical',
                                                           batch_size=batch,
                                                           shuffle=True,
                                                           seed=seed) # set as validation data
# Out:
# Found 3183 images belonging to 8 classes.
# Found 351 images belonging to 8 classes.

# %% [markdown]
# # Transfer learning

# %%
input_shape = (96,96,3)

# %%
# Import Xception base model
base_model = tfk.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=input_shape,
    include_top=False)  # Do not include the ImageNet classifier at the top.

#base_model.summary()
#tfk.utils.plot_model(base_model)

# %%
# freeze the base model
base_model.trainable = True

# %%
# Create a new model on top

inputs = tfk.Input(shape=input_shape)
x = base_model(inputs, training=True)
# x = tfkl.Resizing(img_height, img_width, interpolation='bicubic', name='Resize')

# # flattering
# x = tfkl.Flatten(name='Flattening')(x)

# # classifier with dropout, dense (256), dropout, dense (14)
# x = base_model(inputs)
x = tfkl.GlobalAveragePooling2D()(x)

x = tfkl.Dense(
    2048,                               
    activation='relu',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)

x = tfkl.Dropout(0.4, seed=seed)(x)

x = tfkl.Dense(
    2048,                                
    activation='relu',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)

x = tfkl.Dropout(0.4, seed=seed)(x)

outputs = tfkl.Dense(8, 
    activation='softmax',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)


# Connect input and output through the Model class
model = tfk.Model(inputs, outputs, name='base_model')

# %%
model.compile(optimizer=tfk.optimizers.Adam(),
              loss=tfk.losses.CategoricalCrossentropy(),
              metrics='accuracy')
model.summary()
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  xception (Functional)       (None, 3, 3, 2048)        20861480
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 2048)              4196352
#
#  dropout_4 (Dropout)         (None, 2048)              0
#
#  dense_7 (Dense)             (None, 2048)              4196352
#
#  dropout_5 (Dropout)         (None, 2048)              0
#
#  dense_8 (Dense)             (None, 8)                 16392
#
# =================================================================
# Total params: 29,270,576
# Trainable params: 29,216,048
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
# create class weights
class_distributions = []
for i in range(8):
  class_distributions.append(sum(1 for x in train_gen.labels if x == i))
  
weights = []
total = train_gen.labels.size

for i in range(8):
  weights.append((i,(1/class_distributions[i]) * (total/8.0)))

class_weights  = {cat:weight for (cat,weight) in weights}

# %%
class_weights
# Out:
# {0: 2.38248502994012,
#  1: 0.8323744769874476,
#  2: 0.8593412526997841,
#  3: 0.8668300653594772,
#  4: 0.8341194968553459,
#  5: 1.9993718592964824,
#  6: 0.8237577639751553,
#  7: 0.8706236323851203}

# %%
callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
batch_size= 64
epochs=300

# Train the model
tl_history = model.fit(
          x = train_gen,
          batch_size=batch_size,
          epochs = epochs,
          validation_data = val_gen,
          callbacks = callbacks).history
# Out:
# Epoch 1/300
# 50/50 [==============================] - 163s 3s/step - loss: 1.7207 - accuracy: 0.3918 - val_loss: 1.2013 - val_accuracy: 0.5157
# Epoch 2/300
# 50/50 [==============================] - 213s 4s/step - loss: 1.1214 - accuracy: 0.6280 - val_loss: 0.8952 - val_accuracy: 0.6724
# Epoch 3/300
# 50/50 [==============================] - 244s 5s/step - loss: 0.9250 - accuracy: 0.6871 - val_loss: 0.8962 - val_accuracy: 0.7151
# Epoch 4/300
# 50/50 [==============================] - 238s 5s/step - loss: 0.7936 - accuracy: 0.7405 - val_loss: 0.6460 - val_accuracy: 0.7949
# Epoch 5/300
# 50/50 [==============================] - 236s 5s/step - loss: 0.6891 - accuracy: 0.7848 - val_loss: 0.6729 - val_accuracy: 0.7778
# Epoch 6/300
# 50/50 [==============================] - 242s 5s/step - loss: 0.6172 - accuracy: 0.7992 - val_loss: 0.6318 - val_accuracy: 0.7920
# Epoch 7/300
# 50/50 [==============================] - 218s 4s/step - loss: 0.6412 - accuracy: 0.7999 - val_loss: 0.6024 - val_accuracy: 0.8120
# Epoch 8/300
# 50/50 [==============================] - 226s 5s/step - loss: 0.5585 - accuracy: 0.8184 - val_loss: 0.6326 - val_accuracy: 0.7778
# Epoch 9/300
# 50/50 [==============================] - 235s 5s/step - loss: 0.5216 - accuracy: 0.8241 - val_loss: 0.5533 - val_accuracy: 0.8319
# Epoch 10/300
# 50/50 [==============================] - 238s 5s/step - loss: 0.4726 - accuracy: 0.8423 - val_loss: 0.5557 - val_accuracy: 0.8034
# Epoch 11/300
# 50/50 [==============================] - 243s 5s/step - loss: 0.5153 - accuracy: 0.8354 - val_loss: 0.5589 - val_accuracy: 0.8376
# Epoch 12/300
# 50/50 [==============================] - 258s 5s/step - loss: 0.4731 - accuracy: 0.8464 - val_loss: 0.6584 - val_accuracy: 0.7920
# Epoch 13/300
# 50/50 [==============================] - 244s 5s/step - loss: 0.4390 - accuracy: 0.8577 - val_loss: 0.5586 - val_accuracy: 0.8006
# Epoch 14/300
# 50/50 [==============================] - 235s 5s/step - loss: 0.3842 - accuracy: 0.8706 - val_loss: 0.4655 - val_accuracy: 0.8661
# Epoch 15/300
# 50/50 [==============================] - 236s 5s/step - loss: 0.3528 - accuracy: 0.8853 - val_loss: 0.5503 - val_accuracy: 0.8177
# Epoch 16/300
# 50/50 [==============================] - 237s 5s/step - loss: 0.3894 - accuracy: 0.8743 - val_loss: 0.4932 - val_accuracy: 0.8547
# Epoch 17/300
# 50/50 [==============================] - 236s 5s/step - loss: 0.4795 - accuracy: 0.8492 - val_loss: 0.5511 - val_accuracy: 0.8348
# Epoch 18/300
# 50/50 [==============================] - 237s 5s/step - loss: 0.4133 - accuracy: 0.8718 - val_loss: 0.4978 - val_accuracy: 0.8604
# Epoch 19/300
# 50/50 [==============================] - 233s 5s/step - loss: 0.3503 - accuracy: 0.8816 - val_loss: 0.5182 - val_accuracy: 0.8376
# Epoch 20/300
# 50/50 [==============================] - 238s 5s/step - loss: 0.3324 - accuracy: 0.8916 - val_loss: 0.5548 - val_accuracy: 0.8462
# Epoch 21/300
# 50/50 [==============================] - 241s 5s/step - loss: 0.3592 - accuracy: 0.8860 - val_loss: 0.4749 - val_accuracy: 0.8604
# Epoch 22/300
# 50/50 [==============================] - 238s 5s/step - loss: 0.3048 - accuracy: 0.8938 - val_loss: 0.4180 - val_accuracy: 0.8689
# Epoch 23/300
# 50/50 [==============================] - 240s 5s/step - loss: 0.2409 - accuracy: 0.9215 - val_loss: 0.5959 - val_accuracy: 0.8575
# Epoch 24/300
# 50/50 [==============================] - 246s 5s/step - loss: 0.2434 - accuracy: 0.9240 - val_loss: 0.5835 - val_accuracy: 0.8433
# Epoch 25/300
# 50/50 [==============================] - 241s 5s/step - loss: 0.2339 - accuracy: 0.9211 - val_loss: 0.4887 - val_accuracy: 0.8490
# Epoch 26/300
# 50/50 [==============================] - 238s 5s/step - loss: 0.2648 - accuracy: 0.9139 - val_loss: 0.4323 - val_accuracy: 0.8689
# Epoch 27/300
# 50/50 [==============================] - 238s 5s/step - loss: 0.2277 - accuracy: 0.9281 - val_loss: 0.5309 - val_accuracy: 0.8661
# Epoch 28/300
# 50/50 [==============================] - 241s 5s/step - loss: 0.2301 - accuracy: 0.9306 - val_loss: 0.5139 - val_accuracy: 0.8746
# Epoch 29/300
# 50/50 [==============================] - 239s 5s/step - loss: 0.2127 - accuracy: 0.9337 - val_loss: 0.5302 - val_accuracy: 0.8604
# Epoch 30/300
# 50/50 [==============================] - 236s 5s/step - loss: 0.2534 - accuracy: 0.9227 - val_loss: 0.4544 - val_accuracy: 0.8775
# Epoch 31/300
# 50/50 [==============================] - 240s 5s/step - loss: 0.2079 - accuracy: 0.9337 - val_loss: 0.5016 - val_accuracy: 0.8604
# Epoch 32/300
# 50/50 [==============================] - 243s 5s/step - loss: 0.1957 - accuracy: 0.9372 - val_loss: 0.5558 - val_accuracy: 0.8632
# Epoch 33/300
# 50/50 [==============================] - 176s 3s/step - loss: 0.1535 - accuracy: 0.9504 - val_loss: 0.3989 - val_accuracy: 0.8974
# Epoch 34/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.2069 - accuracy: 0.9328 - val_loss: 0.4481 - val_accuracy: 0.8775
# Epoch 35/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.2278 - accuracy: 0.9343 - val_loss: 0.6162 - val_accuracy: 0.8661
# Epoch 36/300
# 50/50 [==============================] - 134s 3s/step - loss: 0.2169 - accuracy: 0.9375 - val_loss: 0.5395 - val_accuracy: 0.8632
# Epoch 37/300
# 50/50 [==============================] - 137s 3s/step - loss: 0.2384 - accuracy: 0.9325 - val_loss: 0.4674 - val_accuracy: 0.8661
# Epoch 38/300
# 50/50 [==============================] - 140s 3s/step - loss: 0.3008 - accuracy: 0.9152 - val_loss: 0.5406 - val_accuracy: 0.8462
# Epoch 39/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.1720 - accuracy: 0.9419 - val_loss: 0.5490 - val_accuracy: 0.8575
# Epoch 40/300
# 50/50 [==============================] - 140s 3s/step - loss: 0.1884 - accuracy: 0.9419 - val_loss: 0.4166 - val_accuracy: 0.8832
# Epoch 41/300
# 50/50 [==============================] - 142s 3s/step - loss: 0.1394 - accuracy: 0.9557 - val_loss: 0.5522 - val_accuracy: 0.8718
# Epoch 42/300
# 50/50 [==============================] - 144s 3s/step - loss: 0.1549 - accuracy: 0.9548 - val_loss: 0.4557 - val_accuracy: 0.8775
# Epoch 43/300
# 50/50 [==============================] - 141s 3s/step - loss: 0.1531 - accuracy: 0.9519 - val_loss: 0.5084 - val_accuracy: 0.8889
# Epoch 44/300
# 50/50 [==============================] - 140s 3s/step - loss: 0.1419 - accuracy: 0.9560 - val_loss: 0.5138 - val_accuracy: 0.8575
# Epoch 45/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.1379 - accuracy: 0.9522 - val_loss: 0.4647 - val_accuracy: 0.8832
# Epoch 46/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.1310 - accuracy: 0.9566 - val_loss: 0.3841 - val_accuracy: 0.8974
# Epoch 47/300
# 50/50 [==============================] - 141s 3s/step - loss: 0.0961 - accuracy: 0.9670 - val_loss: 0.4689 - val_accuracy: 0.8775
# Epoch 48/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.0996 - accuracy: 0.9695 - val_loss: 0.3643 - val_accuracy: 0.9031
# Epoch 49/300
# 50/50 [==============================] - 141s 3s/step - loss: 0.1107 - accuracy: 0.9673 - val_loss: 0.4432 - val_accuracy: 0.8746
# Epoch 50/300
# 50/50 [==============================] - 137s 3s/step - loss: 0.0955 - accuracy: 0.9667 - val_loss: 0.5844 - val_accuracy: 0.8632
# Epoch 51/300
# 50/50 [==============================] - 137s 3s/step - loss: 0.1230 - accuracy: 0.9595 - val_loss: 0.4731 - val_accuracy: 0.8775
# Epoch 52/300
# 50/50 [==============================] - 136s 3s/step - loss: 0.0929 - accuracy: 0.9680 - val_loss: 0.5467 - val_accuracy: 0.8889
# Epoch 53/300
# 50/50 [==============================] - 137s 3s/step - loss: 0.0924 - accuracy: 0.9705 - val_loss: 0.5119 - val_accuracy: 0.8632
# Epoch 54/300
# 50/50 [==============================] - 137s 3s/step - loss: 0.1158 - accuracy: 0.9667 - val_loss: 0.4912 - val_accuracy: 0.8803
# Epoch 55/300
# 50/50 [==============================] - 139s 3s/step - loss: 0.1438 - accuracy: 0.9614 - val_loss: 0.5264 - val_accuracy: 0.8604
# Epoch 56/300
# 50/50 [==============================] - 142s 3s/step - loss: 0.2763 - accuracy: 0.9252 - val_loss: 0.5502 - val_accuracy: 0.8405
# Epoch 57/300
# 50/50 [==============================] - 142s 3s/step - loss: 0.2427 - accuracy: 0.9340 - val_loss: 0.5003 - val_accuracy: 0.8632
# Epoch 58/300
# 50/50 [==============================] - 141s 3s/step - loss: 0.1530 - accuracy: 0.9554 - val_loss: 0.5022 - val_accuracy: 0.8632
# Epoch 59/300
# 50/50 [==============================] - 139s 3s/step - loss: 0.1173 - accuracy: 0.9588 - val_loss: 0.6458 - val_accuracy: 0.8604
# Epoch 60/300
# 50/50 [==============================] - 140s 3s/step - loss: 0.1215 - accuracy: 0.9632 - val_loss: 0.4707 - val_accuracy: 0.9003
# Epoch 61/300
# 50/50 [==============================] - 138s 3s/step - loss: 0.1263 - accuracy: 0.9604 - val_loss: 0.5050 - val_accuracy: 0.8803
# Epoch 62/300
# 50/50 [==============================] - 142s 3s/step - loss: 0.0956 - accuracy: 0.9702 - val_loss: 0.4475 - val_accuracy: 0.8689
# Epoch 63/300
# 50/50 [==============================] - 136s 3s/step - loss: 0.0909 - accuracy: 0.9702 - val_loss: 0.6032 - val_accuracy: 0.8803

# %%
# Evaluate on validation set
# Trainined with no data augmentation
#model_ = tfk.models.load_model("model/CNN_bn_dropout")
model_test_metrics = model.evaluate(val_gen, return_dict=True)

print()
print("Test metrics without data augmentation")
print(model_test_metrics)
# Out:
# 6/6 [==============================] - 4s 649ms/step - loss: 0.4020 - accuracy: 0.9031
#
# Test metrics without data augmentation
# {'loss': 0.4019758105278015, 'accuracy': 0.9031339287757874}

# %%
model.save("model_Xception22/Xception_ftl22")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 40). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_Xception22/Xception_ftl22\assets
# INFO:tensorflow:Assets written to: model_Xception22/Xception_ftl22\assets
